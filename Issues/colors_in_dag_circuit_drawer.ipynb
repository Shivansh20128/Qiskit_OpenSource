# %%
# Circuit Drawer
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
qc = QuantumCircuit(1, 1)
qc.h(0)
qc.measure(0, 0)
qc.draw(output='mpl', style="clifford")

# %%
qc.draw(output='mpl')

# %%
qc.draw(output='mpl', style="iqp-dark")

# %%
qc.draw(output='mpl', style="bw")

# %%
qc.draw(output='mpl', style="textbook")

# %%
qc.draw(output='mpl', style={'backgroundcolor': '#000000'})

# %%
qc.draw(output='mpl', style={'color':'#0000F'})

# %%
from qiskit.visualization import circuit_drawer
# circuit_drawer(qc, output="mpl", style={"backgroundcolor":"#000000"})
circuit_drawer(qc, output="mpl")

# %%
circuit_drawer(qc, output="mpl", style={"backgroundcolor":"#0000FF"})

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.dagcircuit import DAGCircuit
from qiskit.converters import circuit_to_dag
from qiskit.visualization import dag_drawer
 
q = QuantumRegister(3, 'q')
c = ClassicalRegister(3, 'c')
circ = QuantumCircuit(q, c)
circ.h(q[0])
circ.cx(q[0], q[1])
circ.measure(q[0], c[0])
circ.rz(0.5, q[1]).c_if(c, 2)

dag = circuit_to_dag(circ)
dag_drawer(dag, style="color")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=307x473>
