# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime.fake_provider import FakeSherbrooke
from qiskit.circuit.library import QFTGate

from qiskit import QuantumCircuit


qft = QFTGate(1)

qc = QuantumCircuit(1)
qc.h(0)
qc.sx(0)
qc.z(0)
qc.append(qft.inverse(), [0])
qc.z(0)
qc.sxdg(0)

qc.measure_all()

backend = FakeSherbrooke()
pass_manager=generate_preset_pass_manager(backend=backend, optimization_level=3, **{'layout_method': 'trivial', 'routing_method': 'stochastic', 'translation_method': 'synthesis'})
transpiled_circuit = pass_manager.run(qc)
# Out:
# hello from super passmanager
# hello from super basepassmanager1
# hello from runworkflow
# hello from basecontroller1
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from basecontroller2
# hello from runworkflow2
# hello from super basepassmanager2
# hello from passmanager
#
# hello from super passmanager
# hello from super basepassmanager1
# hello from runworkflow
# hello from basecontroller1
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from highlevelsynthesis
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from super execute
# hello from basecontroller1
# hello from super execute
# hello from basecontroller2
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from highlevelsynthesis
# hello from execute
# hello from super execute
# hello from super execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from execute
# hello from super execute
# hello from highlevelsynthesis
# did you try?:
# Instruction(name='qft_dg', num_qubits=1, num_clbits=0, params=[])
#    ┌───┐
# q: ┤ H ├
#    └───┘
# did you try?:
# Instruction(name='h', num_qubits=1, num_clbits=0, params=[])
#    ┌─────────┐
# q: ┤ U2(0,π) ├
#    └─────────┘
# did you try?:
# Instruction(name='u2', num_qubits=1, num_clbits=0, params=[0.0, 3.141592653589793])
#    ┌─────────────┐
# q: ┤ U3(π/2,0,π) ├
#    └─────────────┘
# did you try?:
# Instruction(name='u3', num_qubits=1, num_clbits=0, params=[1.5707963267948966, 0.0, 3.141592653589793])
#    ┌────────────┐
# q: ┤ U(π/2,0,π) ├
#    └────────────┘
# did you try?:
# Instruction(name='u', num_qubits=1, num_clbits=0, params=[1.5707963267948966, 0.0, 3.141592653589793])
# None
# ---------------------------------------------------------------------------
# TranspilerError                           Traceback (most recent call last)
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passmanager.py:465, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     464 try:
# --> 465     return meth(*meth_args, **meth_kwargs)
#     466 except PassManagerError as ex:
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passmanager.py:226, in PassManager.run(self, circuits, output_name, callback, num_processes)
#     225 print("hello from super passmanager")
# --> 226 return super().run(
#     227     in_programs=circuits,
#     228     callback=callback,
#     229     output_name=output_name,
#     230     num_processes=num_processes,
#     231 )
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/passmanager/passmanager.py:232, in BasePassManager.run(self, in_programs, callback, num_processes, **kwargs)
#     231 print("hello from super basepassmanager1")
# --> 232 out = [
#     233     _run_workflow(program=program, pass_manager=self, callback=callback, **kwargs)
#     234     for program in in_programs
#     235 ]
#     236 print("hello from super basepassmanager2")
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/passmanager/passmanager.py:233, in <listcomp>(.0)
#     231 print("hello from super basepassmanager1")
#     232 out = [
# --> 233     _run_workflow(program=program, pass_manager=self, callback=callback, **kwargs)
#     234     for program in in_programs
#     235 ]
#     236 print("hello from super basepassmanager2")
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/passmanager/passmanager.py:297, in _run_workflow(program, pass_manager, **kwargs)
#     296 print("hello from runworkflow")
# --> 297 passmanager_ir, final_state = flow_controller.execute(
#     298     passmanager_ir=passmanager_ir,
#     299     state=PassManagerState(
#     300         workflow_status=initial_status,
#     301         property_set=PropertySet(),
#     302     ),
#     303     callback=kwargs.get("callback", None),
#     304 )
#     305 print("hello from runworkflow2")
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/passmanager/base_tasks.py:220, in BaseController.execute(self, passmanager_ir, state, callback)
#     219 while True:
# --> 220     passmanager_ir, state = next_task.execute(
#     221         passmanager_ir=passmanager_ir,
#     222         state=state,
#     223         callback=callback,
#     224     )
#     226     try:
#     227         # Sending the object through the generator implies the custom controllers
#     228         # can always rely on the latest data to choose the next task to run.
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/basepasses.py:196, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     195 print("hello from execute")
# --> 196 new_dag, state = super().execute(
#     197     passmanager_ir=passmanager_ir,
#     198     state=state,
#     199     callback=callback,
#     200 )
#     202 if state.workflow_status.previous_run == RunState.SUCCESS:
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/passmanager/base_tasks.py:99, in GenericPass.execute(self, passmanager_ir, state, callback)
#      98 print("hello from super execute")
# ---> 99 ret = self.run(passmanager_ir)
#     100 run_state = RunState.SUCCESS
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:279, in HighLevelSynthesis.run(self, dag)
#     278 print("hello from highlevelsynthesis")
# --> 279 out_dag = self._run(dag, tracker, context, use_ancillas=True, top_level=True)
#     280 return out_dag
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:379, in HighLevelSynthesis._run(self, dag, tracker, context, use_ancillas, top_level)
#     373 # now we are free to synthesize
#     374 else:
#     375     # This returns the synthesized operation and its context (when the result is
#     376     # a DAG, it's the correspondence between its qubits and the global qubits).
#     377     # Also note that the DAG may use auxiliary qubits. The qubits tracker and the
#     378     # current DAG's context are updated in-place.
# --> 379     synthesized, synthesized_context = self._synthesize_operation(
#     380         node.op, qubits, tracker, context, use_ancillas=use_ancillas
#     381     )
#     383 # If the synthesis changed the operation (i.e. it is not None), store the result.
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:607, in HighLevelSynthesis._synthesize_operation(self, operation, qubits, tracker, context, use_ancillas)
#     606 saved_tracker = tracker.copy()
# --> 607 synthesized = self._run(
#     608     as_dag, tracker, inner_context, use_ancillas=use_ancillas, top_level=False
#     609 )
#     610 synthesized_context = inner_context
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:379, in HighLevelSynthesis._run(self, dag, tracker, context, use_ancillas, top_level)
#     373 # now we are free to synthesize
#     374 else:
#     375     # This returns the synthesized operation and its context (when the result is
#     376     # a DAG, it's the correspondence between its qubits and the global qubits).
#     377     # Also note that the DAG may use auxiliary qubits. The qubits tracker and the
#     378     # current DAG's context are updated in-place.
# --> 379     synthesized, synthesized_context = self._synthesize_operation(
#     380         node.op, qubits, tracker, context, use_ancillas=use_ancillas
#     381     )
#     383 # If the synthesis changed the operation (i.e. it is not None), store the result.
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:607, in HighLevelSynthesis._synthesize_operation(self, operation, qubits, tracker, context, use_ancillas)
#     606 saved_tracker = tracker.copy()
# --> 607 synthesized = self._run(
#     608     as_dag, tracker, inner_context, use_ancillas=use_ancillas, top_level=False
#     609 )
#     610 synthesized_context = inner_context
#
#     [... skipping similar frames: HighLevelSynthesis._run at line 379 (2 times), HighLevelSynthesis._synthesize_operation at line 607 (1 times)]
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:607, in HighLevelSynthesis._synthesize_operation(self, operation, qubits, tracker, context, use_ancillas)
#     606 saved_tracker = tracker.copy()
# --> 607 synthesized = self._run(
#     608     as_dag, tracker, inner_context, use_ancillas=use_ancillas, top_level=False
#     609 )
#     610 synthesized_context = inner_context
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:379, in HighLevelSynthesis._run(self, dag, tracker, context, use_ancillas, top_level)
#     373 # now we are free to synthesize
#     374 else:
#     375     # This returns the synthesized operation and its context (when the result is
#     376     # a DAG, it's the correspondence between its qubits and the global qubits).
#     377     # Also note that the DAG may use auxiliary qubits. The qubits tracker and the
#     378     # current DAG's context are updated in-place.
# --> 379     synthesized, synthesized_context = self._synthesize_operation(
#     380         node.op, qubits, tracker, context, use_ancillas=use_ancillas
#     381     )
#     383 # If the synthesis changed the operation (i.e. it is not None), store the result.
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:571, in HighLevelSynthesis._synthesize_operation(self, operation, qubits, tracker, context, use_ancillas)
#     570     if synthesized is None and not self._top_level_only:
# --> 571         synthesized = self._get_custom_definition(operation, indices)
#     573 if synthesized is None:
#     574     # if we didn't synthesize, there was nothing to unroll
#     575     # updating the tracker will be handled upstream
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passes/synthesis/high_level_synthesis.py:659, in HighLevelSynthesis._get_custom_definition(self, inst, qubits)
#     658 if definition is None:
# --> 659     raise TranspilerError(f"HighLevelSynthesis was unable to synthesize {inst}.")
#     661 return definition
#
# TranspilerError: "HighLevelSynthesis was unable to synthesize Instruction(name='u', num_qubits=1, num_clbits=0, params=[1.5707963267948966, 0.0, 3.141592653589793])."
#
# The above exception was the direct cause of the following exception:
#
# TranspilerError                           Traceback (most recent call last)
# Cell In[1], line 22
#      20 backend = FakeSherbrooke()
#      21 pass_manager=generate_preset_pass_manager(backend=backend, optimization_level=3, **{'layout_method': 'trivial', 'routing_method': 'stochastic', 'translation_method': 'synthesis'})
# ---> 22 transpiled_circuit = pass_manager.run(qc)
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passmanager.py:442, in StagedPassManager.run(self, circuits, output_name, callback, num_processes)
#     440 self._update_passmanager()
#     441 print("hello from passmanager\n")
# --> 442 return super().run(circuits, output_name, callback, num_processes=num_processes)
#
# File /Users/Shared/Drive/Qiskit/tutenv/lib/python3.10/site-packages/qiskit/transpiler/passmanager.py:467, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     465     return meth(*meth_args, **meth_kwargs)
#     466 except PassManagerError as ex:
# --> 467     raise TranspilerError(ex.message) from ex
#
# TranspilerError: "HighLevelSynthesis was unable to synthesize Instruction(name='u', num_qubits=1, num_clbits=0, params=[1.5707963267948966, 0.0, 3.141592653589793])."
