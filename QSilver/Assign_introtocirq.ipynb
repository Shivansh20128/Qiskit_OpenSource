# %% [markdown]
# # Instructions
#
# The places where you have enter code, to answer the questions, are marked with `# YOUR CODE HERE`. Once you have written your code you should remove the `raise NotImplementedError()` statement.

# %%
# !pip install cirq
# Out:
# Collecting cirq
#   Downloading cirq-1.3.0-py3-none-any.whl (8.1 kB)
# Collecting cirq-rigetti==1.3.0
#   Downloading cirq_rigetti-1.3.0-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 1.0 MB/s eta 0:00:011
# Collecting cirq-google==1.3.0
#   Downloading cirq_google-1.3.0-py3-none-any.whl (598 kB)
#      |████████████████████████████████| 598 kB 2.0 MB/s eta 0:00:01
# Collecting cirq-ft==1.3.0
#   Downloading cirq_ft-1.3.0-py3-none-any.whl (143 kB)
#      |████████████████████████████████| 143 kB 43.8 MB/s eta 0:00:01
# Collecting cirq-ionq==1.3.0
#   Downloading cirq_ionq-1.3.0-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 1.2 MB/s eta 0:00:011
# Collecting cirq-pasqal==1.3.0
#   Downloading cirq_pasqal-1.3.0-py3-none-any.whl (31 kB)
# Collecting cirq-aqt==1.3.0
#   Downloading cirq_aqt-1.3.0-py3-none-any.whl (27 kB)
# Collecting cirq-web==1.3.0
#   Downloading cirq_web-1.3.0-py3-none-any.whl (596 kB)
#      |████████████████████████████████| 596 kB 466 kB/s eta 0:00:01
# Collecting cirq-core==1.3.0
#   Downloading cirq_core-1.3.0-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 52.7 MB/s eta 0:00:01
# Requirement already satisfied: requests~=2.18 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-aqt==1.3.0->cirq) (2.32.3)
# Requirement already satisfied: pandas in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (2.2.3)
# Requirement already satisfied: scipy in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (1.13.1)
# Requirement already satisfied: typing-extensions>=4.2 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (4.12.2)
# Requirement already satisfied: numpy~=1.16 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (1.26.4)
# Collecting tqdm
#   Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib~=3.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (3.9.2)
# Requirement already satisfied: sympy in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-core==1.3.0->cirq) (1.13.3)
# Collecting networkx>=2.4
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 2.0 MB/s eta 0:00:01
# Collecting sortedcontainers~=2.0
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting duet~=0.2.8
#   Downloading duet-0.2.9-py3-none-any.whl (29 kB)
# Requirement already satisfied: cachetools>=5.3 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-ft==1.3.0->cirq) (5.5.0)
# Requirement already satisfied: nbconvert in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-ft==1.3.0->cirq) (7.16.4)
# Requirement already satisfied: ipywidgets in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-ft==1.3.0->cirq) (8.1.5)
# Requirement already satisfied: attrs in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-ft==1.3.0->cirq) (24.2.0)
# Requirement already satisfied: nbformat in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from cirq-ft==1.3.0->cirq) (5.10.4)
# Collecting google-api-core[grpc]>=1.14.0
#   Downloading google_api_core-2.22.0-py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 40.4 MB/s eta 0:00:01
# Collecting proto-plus>=1.20.0
#   Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 12.2 MB/s eta 0:00:01
# Collecting protobuf>=3.15.0
#   Downloading protobuf-5.28.3-cp38-abi3-macosx_10_9_universal2.whl (414 kB)
#      |████████████████████████████████| 414 kB 11.7 MB/s eta 0:00:01
# Collecting pyquil<4.0.0,>=3.2.0
#   Downloading pyquil-3.5.4-py3-none-any.whl (223 kB)
#      |████████████████████████████████| 223 kB 49.8 MB/s eta 0:00:01
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
#      |████████████████████████████████| 220 kB 55.7 MB/s eta 0:00:01
# Collecting google-auth<3.0.dev0,>=2.14.1
#   Downloading google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 29.2 MB/s eta 0:00:01
# Collecting grpcio<2.0dev,>=1.33.2
#   Downloading grpcio-1.67.1-cp39-cp39-macosx_10_9_universal2.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 1.4 MB/s eta 0:00:01
# Collecting grpcio-status<2.0.dev0,>=1.33.2
#   Downloading grpcio_status-1.67.1-py3-none-any.whl (14 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 3.6 MB/s eta 0:00:01
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (1.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (4.54.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (6.4.5)
# Requirement already satisfied: pillow>=8 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (10.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (24.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib~=3.0->cirq-core==1.3.0->cirq) (3.20.2)
# Collecting pyasn1<0.7.0,>=0.4.6
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 3.2 MB/s eta 0:00:01
# Collecting deprecated<2.0.0,>=1.2.13
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting lark<0.12.0,>=0.11.1
#   Downloading lark-0.11.3.tar.gz (229 kB)
#      |████████████████████████████████| 229 kB 6.7 MB/s eta 0:00:01
# Collecting rpcq<4.0.0,>=3.10.0
#   Downloading rpcq-3.11.0.tar.gz (45 kB)
#      |████████████████████████████████| 45 kB 1.4 MB/s eta 0:00:011
# Collecting tenacity<9.0.0,>=8.2.2
#   Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Collecting types-retry<0.10.0,>=0.9.9
#   Downloading types_retry-0.9.9.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: types-python-dateutil<3.0.0,>=2.8.19 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (2.9.0.20241003)
# Collecting qcs-api-client<0.22.0,>=0.21.0
#   Downloading qcs_api_client-0.21.6-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 290 kB/s eta 0:00:01
# Collecting types-deprecated<2.0.0.0,>=1.2.9.2
#   Downloading types_Deprecated-1.2.9.20240311-py3-none-any.whl (3.5 kB)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.16.0-cp39-cp39-macosx_10_9_x86_64.whl (37 kB)
# Requirement already satisfied: six>=1.5 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->cirq-core==1.3.0->cirq) (1.16.0)
# Collecting iso8601<2.0.0,>=1.0.2
#   Downloading iso8601-1.1.0-py3-none-any.whl (9.9 kB)
# Collecting rfc3339<7.0,>=6.2
#   Downloading rfc3339-6.2-py3-none-any.whl (5.5 kB)
# Collecting httpx<0.24.0,>=0.23.0
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 15.7 MB/s eta 0:00:01
# Collecting toml<0.11.0,>=0.10.2
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (2.9.0)
# Collecting attrs
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 1.2 MB/s eta 0:00:011
# Collecting retrying<2.0.0,>=1.3.3
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting pydantic<2.0.0,>=1.7.2
#   Downloading pydantic-1.10.19-cp39-cp39-macosx_10_9_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 1.0 MB/s eta 0:00:01
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 13.5 MB/s eta 0:00:01
# Requirement already satisfied: certifi in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (2024.8.30)
# Requirement already satisfied: sniffio in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (4.6.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from anyio<5.0,>=3.0->httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from anyio<5.0,>=3.0->httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from requests~=2.18->cirq-aqt==1.3.0->cirq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from requests~=2.18->cirq-aqt==1.3.0->cirq) (2.2.3)
# Collecting msgpack<2.0,>=0.6
#   Using cached msgpack-1.1.0-cp39-cp39-macosx_10_9_x86_64.whl (84 kB)
# Collecting python-rapidjson
#   Downloading python_rapidjson-1.20-cp39-cp39-macosx_10_9_x86_64.whl (229 kB)
#      |████████████████████████████████| 229 kB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: pyzmq>=17 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from rpcq<4.0.0,>=3.10.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (26.2.0)
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#      |████████████████████████████████| 117 kB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: comm>=0.1.3 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (4.0.13)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (5.14.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (3.0.13)
# Requirement already satisfied: ipython>=6.1.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (8.18.1)
# Requirement already satisfied: stack-data in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.6.3)
# Requirement already satisfied: matplotlib-inline in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (2.18.0)
# Requirement already satisfied: jedi>=0.16 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.19.1)
# Requirement already satisfied: decorator in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.2.13)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (5.7.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (3.0.2)
# Requirement already satisfied: beautifulsoup4 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (4.12.3)
# Requirement already satisfied: jinja2>=3.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (3.1.4)
# Requirement already satisfied: bleach!=5.0.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (6.1.0)
# Requirement already satisfied: tinycss2 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (1.3.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (2.1.5)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (8.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (1.5.1)
# Requirement already satisfied: defusedxml in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.7.1)
# Requirement already satisfied: webencodings in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert->cirq-ft==1.3.0->cirq) (0.5.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from jupyter-core>=4.7->nbconvert->cirq-ft==1.3.0->cirq) (4.3.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbclient>=0.5.0->nbconvert->cirq-ft==1.3.0->cirq) (8.6.3)
# Requirement already satisfied: tornado>=6.2 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->cirq-ft==1.3.0->cirq) (6.4.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbformat->cirq-ft==1.3.0->cirq) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from nbformat->cirq-ft==1.3.0->cirq) (2.20.0)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.22.0-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 8.4 MB/s  eta 0:00:01
#   Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 1.6 MB/s eta 0:00:011
#   Downloading jsonschema-4.21.0-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 584 kB/s  eta 0:00:01
#   Downloading jsonschema-4.20.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 1.5 MB/s eta 0:00:011
#   Downloading jsonschema-4.19.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.3 MB/s eta 0:00:011
#   Downloading jsonschema-4.19.1-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.3 MB/s eta 0:00:011
#   Downloading jsonschema-4.19.0-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.3 MB/s eta 0:00:011
#   Downloading jsonschema-4.18.6-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.3 MB/s eta 0:00:011
#   Downloading jsonschema-4.18.5-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 914 kB/s eta 0:00:011
#   Downloading jsonschema-4.18.4-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 1.5 MB/s eta 0:00:011
#   Downloading jsonschema-4.18.3-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 1.5 MB/s eta 0:00:011
#   Downloading jsonschema-4.18.2-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 1.5 MB/s eta 0:00:011
#   Downloading jsonschema-4.18.1-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 18.5 MB/s eta 0:00:01
#   Downloading jsonschema-4.18.0-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 1.5 MB/s eta 0:00:011
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 1.6 MB/s eta 0:00:011
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.20.0-cp39-cp39-macosx_10_9_universal2.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: soupsieve>1.2 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->cirq-ft==1.3.0->cirq) (2.6)
# Requirement already satisfied: tzdata>=2022.7 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from pandas->cirq-core==1.3.0->cirq) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from pandas->cirq-core==1.3.0->cirq) (2024.2)
# Collecting ruamel.yaml.clib>=0.2.7
#   Downloading ruamel.yaml.clib-0.2.12.tar.gz (225 kB)
#      |████████████████████████████████| 225 kB 2.0 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pure-eval in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->cirq-ft==1.3.0->cirq) (2.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/Shared/Drive/Qiskit/qiskitenv/lib/python3.9/site-packages (from sympy->cirq-core==1.3.0->cirq) (1.3.0)
# Using legacy 'setup.py install' for lark, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for rpcq, since package 'wheel' is not installed.
# Building wheels for collected packages: ruamel.yaml.clib
#   Building wheel for ruamel.yaml.clib (PEP 517) ... done
#   Created wheel for ruamel.yaml.clib: filename=ruamel.yaml.clib-0.2.12-cp39-cp39-macosx_10_9_universal2.whl size=273592 sha256=88f2b35435a8978052dba04f5f993d9182133bc38295d8abada5459c5a77dc4e
#   Stored in directory: /Users/Shivansh/Library/Caches/pip/wheels/51/2a/cd/d139e8fd1b596726d9b65ff18b94896cbeb507552848346222
# Successfully built ruamel.yaml.clib
# Installing collected packages: rfc3986, pyrsistent, pyasn1, attrs, ruamel.yaml.clib, rsa, pyasn1-modules, protobuf, jsonschema, httpcore, wrapt, toml, ruamel.yaml, rfc3339, retrying, python-rapidjson, pydantic, proto-plus, msgpack, iso8601, httpx, grpcio, googleapis-common-protos, google-auth, types-retry, types-deprecated, tqdm, tenacity, sortedcontainers, rpcq, qcs-api-client, networkx, lark, grpcio-status, google-api-core, duet, deprecated, pyquil, cirq-core, cirq-web, cirq-rigetti, cirq-pasqal, cirq-ionq, cirq-google, cirq-ft, cirq-aqt, cirq
#   Attempting uninstall: attrs
#     Found existing installation: attrs 24.2.0
#     Uninstalling attrs-24.2.0:
#       Successfully uninstalled attrs-24.2.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.23.0
#     Uninstalling jsonschema-4.23.0:
#       Successfully uninstalled jsonschema-4.23.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.6
#     Uninstalling httpcore-1.0.6:
#       Successfully uninstalled httpcore-1.0.6
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.2
#     Uninstalling httpx-0.27.2:
#       Successfully uninstalled httpx-0.27.2
#     Running setup.py install for rpcq ... done
#     Running setup.py install for lark ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# referencing 0.35.1 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# qiskit-ibm-runtime 0.30.0 requires pydantic>=2.5.0, but you have pydantic 1.10.19 which is incompatible.
# jupyterlab 4.2.5 requires httpx>=0.25.0, but you have httpx 0.23.3 which is incompatible.
# jupyterlab-server 2.27.3 requires jsonschema>=4.18.0, but you have jsonschema 4.17.3 which is incompatible.
# jupyter-events 0.10.0 requires jsonschema[format-nongpl]>=4.18.0, but you have jsonschema 4.17.3 which is incompatible.
# Successfully installed attrs-21.4.0 cirq-1.3.0 cirq-aqt-1.3.0 cirq-core-1.3.0 cirq-ft-1.3.0 cirq-google-1.3.0 cirq-ionq-1.3.0 cirq-pasqal-1.3.0 cirq-rigetti-1.3.0 cirq-web-1.3.0 deprecated-1.2.14 duet-0.2.9 google-api-core-2.22.0 google-auth-2.36.0 googleapis-common-protos-1.65.0 grpcio-1.67.1 grpcio-status-1.67.1 httpcore-0.16.3 httpx-0.23.3 iso8601-1.1.0 jsonschema-4.17.3 lark-0.11.3 msgpack-1.1.0 networkx-3.2.1 proto-plus-1.25.0 protobuf-5.28.3 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-1.10.19 pyquil-3.5.4 pyrsistent-0.20.0 python-rapidjson-1.20 qcs-api-client-0.21.6 retrying-1.3.4 rfc3339-6.2 rfc3986-1.5.0 rpcq-3.11.0 rsa-4.9 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.12 sortedcontainers-2.4.0 tenacity-8.5.0 toml-0.10.2 tqdm-4.67.0 types-deprecated-1.2.9.20240311 types-retry-0.9.9.4 wrapt-1.16.0
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/Shared/Drive/Qiskit/qiskitenv/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ## Question 1 (3 points)
#
# Implement the function `create_circuit_1` that has
#
# * Inputs: None
# * Returns: a `cirq.Circuit` object of 5 qubits.
#
# The function implements, in order, the following operations:
#
# 1. Construct a quantum circuit with 5 qubits.
# 2. Apply the $H$ gate to each qubit.
# 3. Apply the $Z$ gate to qubits in position 0,2 and 4.
# 4. Apply the $H$ gate to each qubit.

# %%
import cirq
from cirq import H, Z

def create_circuit_1(): 

    circuit = cirq.Circuit()
    # Do not modify anything above
    qubits = [cirq.LineQubit(i) for i in range(5)]
    circuit.append(H(qubit) for qubit in qubits)
    
    # Apply the Z gate to qubits 0, 2, and 4
    circuit.append(Z(qubits[i]) for i in [0, 2, 4])
    
    # Apply the H gate to each qubit again
    circuit.append(H(qubit) for qubit in qubits)
    
    
    # YOUR CODE HERE

    # Do not modify anything below
    return circuit

# %% [markdown]
# In the following cell, there is some code that will help you make sure your solution is correct. You can modify this code as you wish. You may also create more cells and write more code to test your own solution.

# %%
circuit = create_circuit_1()
print(circuit)
# Out:
# 0: ───H───Z───H───
#
# 1: ───H───H───────
#
# 2: ───H───Z───H───
#
# 3: ───H───H───────
#
# 4: ───H───Z───H───

# %% [markdown]
# # How autograding will work in this workshop
# In the next cell, there are some hidden tests, not available to you, that will be used to *grade* if your solution is correct, once you submit this file back on Canvas.
#
# You will be notified which of these test cells pass and which fail as a comment on your Canvas assignment.

# %%
# hidden tests in this cell will be used for grading.

# %% [markdown]
# ## Question 2 (4 points)
#
# Implement the function `create_circuit_2` that has
#
# * Inputs: None
# * Returns: (1) a `cirq.Circuit` object of 5 qubits, (2) measurement results of the circuit for 1000 iterations (a `collections.Counter` object).
#
# The function implements, in order, the following operations:
#
# 1. Construct a quantum circuit with 5 qubits.
# 2. Apply the $H$ gate to each qubit
# 3. Apply $NOT$ gate to qubit in position 0 controlled by the other qubits. (1,2,3,4)
# 4. Measure qubit 0
# 5. Run your circuit for 1000 times
#
#
#
# You should observe 0 and 1 almost with equal probability.

# %%
# import cirq
from cirq import X, H, measure

def create_circuit_2():
    
    circuit = cirq.Circuit()
    # Do not modify anything above
    qubits = [cirq.LineQubit(i) for i in range(5)]
    circuit.append(H(qubit) for qubit in qubits)
    
    # Apply the controlled-NOT gate to qubit 0 with controls on qubits 1, 2, 3, and 4
    circuit.append(X(qubits[0]).controlled_by(*qubits[1:]))
    
    # Measure qubit 0
    circuit.append(measure(qubits[0], key='result'))
    
    # Run the circuit 1000 times and collect results
    simulator = cirq.Simulator()
    samples = simulator.run(circuit, repetitions=1000)
    
    
    # YOUR CODE HERE
    
    # Do not modify anything below
    
    result = samples.histogram(key='result')
    return circuit, result

# %%
# You can check your code by running this cell
circuit, result = create_circuit_2()
print(circuit)
print(result)
# Out:
# 0: ───H───X───M('result')───
#           │
# 1: ───H───@─────────────────
#           │
# 2: ───H───@─────────────────
#           │
# 3: ───H───@─────────────────
#           │
# 4: ───H───@─────────────────
# Counter({0: 502, 1: 498})

# %%
# hidden tests in this cell will be used for grading.

# %% [markdown]
# ## Question 3 (3 points)
#
#
# Implement the function `create_circuit_3`
#
# * Inputs: None
# * Returns: (1) a `cirq.Circuit` object of 2 qubits, (2) a `numpy.ndarray` object that is the unitary matrix associated with the circuit.
#
# The function implements, in order, the following operations:
#
# 1. Construct a quantum circuit with 2 qubits.
# 2. Apply $CNOT$ gate where qubit 0 is the control and qubit 1 is the target qubit
# 3. Apply $CNOT$ gate where qubit 1 is the control and qubit 0 is the target qubit
# 4. Apply $CNOT$ gate where qubit 0 is the control and qubit 1 is the target qubit
# 5. Obtain the unitary matrix representation of your circuit.
#
# _Note: The circuit you implemented swaps the qubits 0 and 1._

# %%
import cirq
from cirq import CX

def create_circuit_3():
    
    circuit = cirq.Circuit()
    # Do not modify anything above
    
    # YOUR CODE HERE
    
    # Do not modify anything below

    return circuit, unitary_matrix

# %%
# You can check your code here by printing the circuit and the matrix
circuit, matrix = create_circuit_3()
print(circuit)
print(matrix)

# %%
# hidden tests in this cell will be used for grading.
